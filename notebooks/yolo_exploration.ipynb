# %% [markdown]
# # Test the actual YOLO model

# %%
import os 

os.getcwd()
# Out:
# '/Users/ThomasStockl/Documents/Study/Gitportfolio/tennis_computer_vision/notebooks'

# %%
from pathlib import Path

input_img = Path("./../data/raw/tennis-detection-1/train/images/synframe20_jpg.rf.03de41d39bbb9a919f08a9fdc5ddc996.jpg")
output_folder = Path("./../data/processed/exploring")

# %%
print(input_img.exists())
print(output_folder.exists())
# Out:
# True
# False

# %%
from ultralytics import YOLO
model = YOLO("yolo26n.pt")

model.predict(
    source = input_img,
    save = True,
    project = output_folder,
    exist_ok = True
)
# Out:
# image 1/1 /Users/ThomasStockl/Documents/Study/Gitportfolio/tennis_computer_vision/notebooks/../data/raw/tennis-detection-1/train/images/synframe20_jpg.rf.03de41d39bbb9a919f08a9fdc5ddc996.jpg: 384x640 3 persons, 1 chair, 314.3ms
# Speed: 26.6ms preprocess, 314.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to /Users/ThomasStockl/Documents/Study/Gitportfolio/tennis_computer_vision/notebooks/runs/data/processed/exploring/predict
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
# ...
